# %% [markdown]
# <a href="https://colab.research.google.com/github/ErnestSun916/bigdata/blob/main/%E3%80%8C0420%E6%9C%9F%E4%B8%AD%E8%80%83%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)

# %%
library(ggplot2)

# %%
NBA1718<-fetch_NBAPlayerStatistics("17-18")

# %%
install.packages("data.table")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(data.table)

# %%
NBA1718DT<-data.table(NBA1718)

# %%
NBA1718OrderM<-NBA1718[order(NBA1718$TotalMinutesPlayed,decreasing=T),]

# %%
NBA1718OrderM[1:20,"Name"]
# Out:
#  [1] "Lebron James"     "Khris Middleton"  "Andrew Wiggins"   "Bradley Beal"
#  [5] "Jrue Holiday"     "Cj Mccollum"      "Karl-antho Towns" "Russel Westbrook"
#  [9] "Paul George"      "Gi Antetokounmpo" "Anthony Davis"    "Kemba Walker"
# [13] "Ben Simmons"      "Taj Gibson"       "Demar Derozan"    "Josh Richardson"
# [17] "Will Barton"      "Damian Lillard"   "Tobias Harris"    "Donovan Mitchell"

# %%
subset(NBA1718,Team=="GSW")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 41  NBA    Jordan Bell      GSW  PF       56           808
# 60  NBA    Chris Boucher    GSW  PF        1             1
# 90  NBA    Omri Casspi      GSW  SF       53           740
# 109 NBA    Quinn Cook       GSW  PG       33           740
# 121 NBA    Stephen Curry    GSW  PG       51          1637
# 144 NBA    Kevin Durant     GSW  SF       68          2327
# 188 NBA    Draymond Green   GSW  PF       70          2285
# 234 NBA    Andre Iguodala   GSW  SF       64          1626
# 264 NBA    Damian Jones     GSW  C        15            89
# 300 NBA    Shaun Livingston GSW  PG       71          1134
# 301 NBA    Kevon Looney     GSW  SF       66           910
# 321 NBA    Patrick Mccaw    GSW  SF       55           962
# 327 NBA    Javale Mcgee     GSW  C        65           611
# 387 NBA    Zaza Pachulia    GSW  C        69           967
# 480 NBA    Klay Thompson    GSW  SG       73          2491
# ...

# %%
NBA1718[grepl("Curry",NBA1718$Name),]
# Out:
#     League Name          Team Position GamesPlayed TotalMinutesPlayed
# 121 NBA    Stephen Curry GSW  PG       51          1637
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 121 428            863                 212        500             ⋯ 81
#     Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 121 153       8      114           1                 1346        2
#     Ejections FlagrantFouls GamesStarted
# 121 0         0             51

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1718)
# Out:
# plot without title

# %%
df<-data.frame(gp=factor(rep(letters[1:3],each=10)),y=rnorm(30))

# %%
ggplot(df,aes(gp,y=y))+geom_point()
# Out:
# plot without title

# %%
ggplot(df,aes(x=gp,y=y))+geom_boxplot()
# Out:
# plot without title

# %%
df$z<-df$y+rnorm(30)

# %%
ggplot(df,aes(x=z,y=y))+geom_line()+facet_grid(gp~.)
# Out:
# plot without title

# %%
ggplot(df,aes(x=z,y=y))+geom_point()+facet_grid(gp~.)+geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
