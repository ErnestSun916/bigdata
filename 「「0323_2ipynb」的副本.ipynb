# %% [markdown]
# <a href="https://colab.research.google.com/github/ErnestSun916/bigdata/blob/main/%E3%80%8C%E3%80%8C0323_2ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)

# %%
library(ggplot2)

# %%
NBA1920<-fetch_NBAPlayerStatistics("19-20")

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,
data=NBA1920,
facets=Position~.)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,
data=NBA1920,
facets=.~Position)
# Out:
# plot without title

# %%
qplot(TotalPoints,data=NBA1920,
facets=Position~.,binwidth=10)
# Out:
# plot without title

# %%
qplot(TotalPoints,data=NBA1920,
facets=Position~.,binwidth=100)
# Out:
# plot without title
