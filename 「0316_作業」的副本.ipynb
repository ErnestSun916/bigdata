# %% [markdown]
# <a href="https://colab.research.google.com/github/ErnestSun916/bigdata/blob/main/%E3%80%8C0316_%E4%BD%9C%E6%A5%AD%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system("ls",TRUE)
# Out:
# [1] "1101.csv"    "sample_data"

# %%
library(readr)

# %%
dataset<-read.csv("1101.csv")

# %%
dataset
# Out:
#    區域別 性別 總計總計 總計本國籍合計 總計本國籍已設籍 總計本國籍未設籍
# 1  臺南市 男   266      264            264              0
# 2  臺南市 女   266      234            234              0
# 3  新營區 男     7        7              7              0
# 4  新營區 女     7        7              7              0
# 5  鹽水區 男     2        2              2              0
# 6  鹽水區 女     2        2              2              0
# 7  白河區 男     2        2              2              0
# 8  白河區 女     2        2              2              0
# 9  柳營區 男     5        5              5              0
# 10 柳營區 女     5        4              4              0
# 11 後壁區 男     4        4              4              0
# 12 後壁區 女     4        3              3              0
# 13 東山區 男     2        2              2              0
# 14 東山區 女     2        1              1              0
# 15 麻豆區 男     9        8              8              0
# 16 麻豆區 女     9        7              7              0
# 17 下營區 男     4        4              4              0
# ...

# %%
head(dataset$性別,n=10)
# Out:
#  [1] "男" "女" "男" "女" "男" "女" "男" "女" "男" "女"

# %%
tail(dataset$總計港澳地區合計)
# Out:
# [1] 0 0 0 0 0 0
